# %%
print(pd.Series(np.array([1,2,3,4,5,6,7]), index=['a','b','c','d','e','f','g'])[pd.Series(np.array([1,2,3,4,5,6,7]), index=['a','b','c','d','e','f','g'])>2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d8cae1f37b0d> in <module>
# ----> 1 print(pd.Series(np.array([1,2,3,4,5,6,7]), index=['a','b','c','d','e','f','g'])[pd.Series(np.array([1,2,3,4,5,6,7]), index=['a','b','c','d','e','f','g'])>2])
#
# NameError: name 'pd' is not defined
